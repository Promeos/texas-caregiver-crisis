# %% [markdown]
# # 01 — Provider Classification
#
# **Goal:** Confirm whether target providers (e.g., Council Oaks Community Options) are licensed as ICF/IID, operating under HCS, or both. This single fact changes every dollar model.
#
# **Data Sources:**
# - HHSC Provider Lookup (hhs.texas.gov)
# - TMHP provider enrollment data
# - PPP/SBA loan databases (federalpay.org)
#
# **Key Questions:**
# 1. What program type(s) does the provider operate under?
# 2. How many homes/beds are licensed?
# 3. What does PPP data tell us about headcount and payroll?

# %%
import pandas as pd
import sys
sys.path.insert(0, '../src')

from texas_hhcs.rates import ProgramType

# %% [markdown]
# ## Provider Lookup
#
# Use HHSC provider search to confirm licensing type and location.

# %%
# TODO: Query HHSC provider data
# Confirm: ICF/IID vs HCS vs mixed

# %% [markdown]
# ## PPP Loan Cross-Reference
#
# PPP ≈ 2.5× monthly payroll. Use reported loan amount to estimate monthly payroll and verify against expected headcount.
#
# Council Oaks: Jobs Retained = 106, loan ~$600k → implies monthly payroll ~$240k.

# %%
# TODO: Load PPP data and cross-reference
ppp_loan = 600_000  # approximate
monthly_payroll_est = ppp_loan / 2.5
print(f"Estimated monthly payroll: ${monthly_payroll_est:,.0f}")
